# %%
2+3
# Out:
# 5

# %%
2-4
# Out:
# -2

# %%
33*11
# Out:
# 363

# %%
34/3
# Out:
# 11.333333333333334

# %% [markdown]
# Modulo or "Mod" operator: Gives the remainder after division operation.

# %%
7%4
# Out:
# 3

# %%
3%2
# Out:
# 1

# %%
50%2333
# Out:
# 50

# %%
23%2
# Out:
# 1

# %%
2**2
# Out:
# 4

# %%
3**3
# Out:
# 27

# %%
3**2
# Out:
# 9

# %%
3**4
# Out:
# 81

# %%
2+3*10
# Out:
# 32

# %% [markdown]
# Used 'Order of Operations' when multiple operatores are included.

# %%
9+3
# Out:
# 12

# %%
(6+3)*(8+1)
# Out:
# 81

# %%
1/8
# Out:
# 0.125

# %%
0/2
# Out:
# 0.0

# %%
0/2 + 0/4 + 1/8
# Out:
# 0.125

# %% [markdown]
# https://docs.python.org/2/tutorial/floatingpoint.html

# %%
0.1+0.2-0.3
# Out:
# 5.551115123125783e-17

# %%
2**2
# Out:
# 4

# %%
30/5
# Out:
# 6.0

# %%
5*6.25
# Out:
# 31.25

# %%
10 * 5 + (2**2) + (31.25/5) +50 -10
# Out:
# 100.25

# %%
sqrt()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-898b4dbc6ab0> in <module>
# ----> 1 sqrt()
#
# NameError: name 'sqrt' is not defined

# %%
import math

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
4**0.5!
# Out:
#   File "<ipython-input-10-4fb6d97ab6e6>", line 1
#     4**0.5!
#           ^
# SyntaxError: invalid syntax

# %%
0.1+0.2-0.5
# Out:
# -0.19999999999999996
